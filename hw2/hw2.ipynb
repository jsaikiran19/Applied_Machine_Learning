# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.model_selection import train_test_split,StratifiedKFold, cross_val_score
from sklearn.metrics import mean_squared_error, accuracy_score

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.datasets import load_breast_cancer

# %%
X,y = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
#No missing values
X.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values,y,test_size=0.3,random_state=42)

# %%
def euclidian_distance(a,b):
    return math.sqrt(sum([(a[i]-b[i])**2 for i in range(len(a))]))

# %%
def classify(X,centroids):
    c1,c2 = centroids
    return np.array([ 'A' if euclidian_distance(c1,X[i])<euclidian_distance(c2,X[i]) else 'B' for i in range(len(X))])

# %%
def KMeans(X,k=2):
    c1,c2 = X[np.random.randint(0,len(X))], X[np.random.randint(0,len(X))]
    classes = classify(X,(c1,c2))
    while True:
        c1 = (np.sum(X[classes=='A'],axis=0) / len(X[classes=='A']))
        c2 = (np.sum(X[classes=='B'],axis=0) / len(X[classes=='B']))
        temp = classify(X,(c1,c2))
        if np.array_equal(temp,classes):
            break
        classes = temp
    return (classes, (c1,c2))

# %%
def kmeans_predict(X,centroids):
    c1,c2 = centroids
    classes = classify(X,(c1,c2))
    return classes

# %%
pred, centroids = KMeans(X_train)

# %%
cluster_with_max = pd.value_counts(pred).keys()[0]

# %%
label_with_max_values = pd.value_counts(y_train).keys()[0]

# %%
cluster_with_max,label_with_max_values
# Out:
# ('A', 1)

# %% [markdown]
# Because clustering cannot assign a class in the y_train, we are reassigning the most predicted cluster with the most predicted label using y_train.

# %%
for i in range(10):
    test_preds = kmeans_predict(X_test,centroids)
    test_pred = np.where(test_preds == cluster_with_max, label_with_max_values,pd.value_counts(y_train).keys()[1])
    print(accuracy_score(y_test, test_pred))
# Out:
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176
# 0.8596491228070176

# %% [markdown]
# Running k-means 10 times with different centroids still results in the same accuracy because eventually all converge to the same centroids.

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf.fit(X_train,y_train)
accuracy_score(y_test,rf.predict(X_test))
# Out:
# 0.9649122807017544

# %% [markdown]
# Yes, using a supervised algorithm results in a better accuracy.

# %% [markdown]
# # Gradient Descent

# %%
def gradient_descent(gradient, fn, iterations=10, alpha=0.5, theta=np.array([0,0])):
    t = 1
    while t<=iterations:
        theta = theta-alpha*(gradient(theta[0],theta[1]))
        print('function value: {} at iteration {}'.format(fn(theta[0],theta[1]),t))
        t+=1
    return theta

# %%
theta_1 = theta_2 = np.array([0,0])
alpha = 0.5
f1 = lambda x,y: (x-2)**2 + (y-3)**2
f2 = lambda x,y: (1-(y-3))**2 + 20*((x+3)-(y-3)**2)**2


grad_f1 = lambda x,y: np.array([2*(x-2),2*(y-3)])

grad_f2 = lambda x,y: np.array([40*(x+3-(y-3)**2), -2*(4-y)-(80*(-((y-3)**2)+x+3)*(y-3))])

# %%
theta_1 = gradient_descent(grad_f1,f1)
print('Final value of theta where f1 is the lowest:{}'.format(theta_1))
# Out:
# function value: 0.0 at iteration 1
# function value: 0.0 at iteration 2
# function value: 0.0 at iteration 3
# function value: 0.0 at iteration 4
# function value: 0.0 at iteration 5
# function value: 0.0 at iteration 6
# function value: 0.0 at iteration 7
# function value: 0.0 at iteration 8
# function value: 0.0 at iteration 9
# function value: 0.0 at iteration 10
# Final value of theta where f1 is the lowest:[2. 3.]

# %%
theta_2 = gradient_descent(grad_f2,f2,100)
print('Final value of theta where f2 is the lowest:{}'.format(theta_2))
# Out:
# function value: 5402136508880.0 at iteration 1
# function value: 1.0094435881067787e+42 at iteration 2
# function value: 6.583034563721081e+129 at iteration 3
# function value: inf at iteration 4
# function value: inf at iteration 5
# function value: nan at iteration 6
# function value: nan at iteration 7
# function value: nan at iteration 8
# function value: nan at iteration 9
# function value: nan at iteration 10
# function value: nan at iteration 11
# function value: nan at iteration 12
# function value: nan at iteration 13
# function value: nan at iteration 14
# function value: nan at iteration 15
# function value: nan at iteration 16
# function value: nan at iteration 17
# function value: nan at iteration 18
# function value: nan at iteration 19
# function value: nan at iteration 20
# function value: nan at iteration 21
# function value: nan at iteration 22
# function value: nan at iteration 23
# function value: nan at iteration 24
# function value: nan at iteration 25
# function value: nan at iteration 26
# function value: nan at iteration 27
# function value: nan at iteration 28
# function value: nan at iteration 29
# function value: nan at iteration 30
# function value: nan at iteration 31
# function value: nan at iteration 32
# function value: nan at iteration 33
# function value: nan at iteration 34
# function value: nan at iteration 35
# function value: nan at iteration 36
# function value: nan at iteration 37
# function value: nan at iteration 38
# function value: nan at iteration 39
# function value: nan at iteration 40
# function value: nan at iteration 41
# function value: nan at iteration 42
# function value: nan at iteration 43
# function value: nan at iteration 44
# function value: nan at iteration 45
# function value: nan at iteration 46
# function value: nan at iteration 47
# function value: nan at iteration 48
# function value: nan at iteration 49
# function value: nan at iteration 50
# function value: nan at iteration 51
# function value: nan at iteration 52
# function value: nan at iteration 53
# function value: nan at iteration 54
# function value: nan at iteration 55
# function value: nan at iteration 56
# function value: nan at iteration 57
# function value: nan at iteration 58
# function value: nan at iteration 59
# function value: nan at iteration 60
# function value: nan at iteration 61
# function value: nan at iteration 62
# function value: nan at iteration 63
# function value: nan at iteration 64
# function value: nan at iteration 65
# function value: nan at iteration 66
# function value: nan at iteration 67
# function value: nan at iteration 68
# function value: nan at iteration 69
# function value: nan at iteration 70
# function value: nan at iteration 71
# function value: nan at iteration 72
# function value: nan at iteration 73
# function value: nan at iteration 74
# function value: nan at iteration 75
# function value: nan at iteration 76
# function value: nan at iteration 77
# function value: nan at iteration 78
# function value: nan at iteration 79
# function value: nan at iteration 80
# function value: nan at iteration 81
# function value: nan at iteration 82
# function value: nan at iteration 83
# function value: nan at iteration 84
# function value: nan at iteration 85
# function value: nan at iteration 86
# function value: nan at iteration 87
# function value: nan at iteration 88
# function value: nan at iteration 89
# function value: nan at iteration 90
# function value: nan at iteration 91
# function value: nan at iteration 92
# function value: nan at iteration 93
# function value: nan at iteration 94
# function value: nan at iteration 95
# function value: nan at iteration 96
# function value: nan at iteration 97
# function value: nan at iteration 98
# function value: nan at iteration 99
# function value: nan at iteration 100
# Final value of theta where f2 is the lowest:[nan nan]
# <ipython-input-17-cf7bfcf472ba>:4: RuntimeWarning: overflow encountered in double_scalars
#   f2 = lambda x,y: (1-(y-3))**2 + 20*((x+3)-(y-3)**2)**2
# <ipython-input-17-cf7bfcf472ba>:9: RuntimeWarning: overflow encountered in double_scalars
#   grad_f2 = lambda x,y: np.array([40*(x+3-(y-3)**2), -2*(4-y)-(80*(-((y-3)**2)+x+3)*(y-3))])
# <ipython-input-17-cf7bfcf472ba>:4: RuntimeWarning: invalid value encountered in double_scalars
#   f2 = lambda x,y: (1-(y-3))**2 + 20*((x+3)-(y-3)**2)**2
# <ipython-input-17-cf7bfcf472ba>:9: RuntimeWarning: invalid value encountered in double_scalars
#   grad_f2 = lambda x,y: np.array([40*(x+3-(y-3)**2), -2*(4-y)-(80*(-((y-3)**2)+x+3)*(y-3))])

# %% [markdown]
# Because the learning rate is high and the function is a polynomial with degree 4 the gradient increases exponentially, which will not result in any solution. Using the second order approximation of gradient descent might result in better values.

# %%
hessian_f2 = lambda x, y: np.linalg.inv(np.array([[40, -80*(y-3)],[-80*(y-3), 240*y*y-1440*y-80*x+1992]]))

# %%
def gradient_descent_hessian(gradient, fn, iterations=10, alpha=0.5, theta=np.array([0,0])):
    t = 1
    while t<=iterations:
        theta = theta-alpha* np.dot(hessian_f2(theta[0],theta[1]),(gradient(theta[0],theta[1])))
        print('function value: {} at iteration {}'.format(fn(theta[0],theta[1]),t))
        t+=1
    return theta

# %%
theta_2 = gradient_descent_hessian(grad_f2,f2,100)
print('Final value of theta where f2 is the lowest:{}'.format(theta_2))
# Out:
# function value: 195.94838274785747 at iteration 1
# function value: 60.85145579798514 at iteration 2
# function value: 26.94124038048553 at iteration 3
# function value: 18.268910868706357 at iteration 4
# function value: 15.856669565772235 at iteration 5
# function value: 14.979947942497637 at iteration 6
# function value: 14.475395426294517 at iteration 7
# function value: 14.062671913806108 at iteration 8
# function value: 13.676650317255728 at iteration 9
# function value: 13.303160055191265 at iteration 10
# function value: 12.939493417720895 at iteration 11
# function value: 12.585248269747934 at iteration 12
# function value: 12.240349061245292 at iteration 13
# function value: 11.904689082405275 at iteration 14
# function value: 11.578103375871901 at iteration 15
# function value: 11.26039098200151 at iteration 16
# function value: 10.951334166928296 at iteration 17
# function value: 10.650709685508927 at iteration 18
# function value: 10.358294628150782 at iteration 19
# function value: 10.073869277830601 at iteration 20
# function value: 9.797218436576918 at iteration 21
# function value: 9.528131994489373 at iteration 22
# function value: 9.266405130490721 at iteration 23
# function value: 9.011838336253511 at iteration 24
# function value: 8.764237356420573 at iteration 25
# function value: 8.523413090155206 at iteration 26
# function value: 8.289181475729102 at iteration 27
# function value: 8.061363368582036 at iteration 28
# function value: 7.8397844178484855 at iteration 29
# function value: 7.624274943725212 at iteration 30
# function value: 7.414669816790664 at iteration 31
# function value: 7.210808339779039 at iteration 32
# function value: 7.0125341320190016 at iteration 33
# function value: 6.819695016606436 at iteration 34
# function value: 6.632142910313172 at iteration 35
# function value: 6.449733716201644 at iteration 36
# function value: 6.272327218900392 at iteration 37
# function value: 6.0997869824885065 at iteration 38
# function value: 5.931980250934439 at iteration 39
# function value: 5.7687778510335574 at iteration 40
# function value: 5.610054097789028 at iteration 41
# function value: 5.455686702180981 at iteration 42
# function value: 5.305556681269729 at iteration 43
# function value: 5.159548270579621 at iteration 44
# function value: 5.01754883871092 at iteration 45
# function value: 4.879448804128128 at iteration 46
# function value: 4.745141554073955 at iteration 47
# function value: 4.614523365559232 at iteration 48
# function value: 4.487493328379762 at iteration 49
# function value: 4.363953270112244 at iteration 50
# function value: 4.243807683042192 at iteration 51
# function value: 4.126963652977698 at iteration 52
# function value: 4.013330789903828 at iteration 53
# function value: 3.90282116043334 at iteration 54
# function value: 3.7953492220102425 at iteration 55
# function value: 3.6908317588236947 at iteration 56
# function value: 3.5891878193905096 at iteration 57
# function value: 3.4903386557655014 at iteration 58
# function value: 3.3942076643396857 at iteration 59
# function value: 3.30072032818724 at iteration 60
# function value: 3.209804160922933 at iteration 61
# function value: 3.121388652032593 at iteration 62
# function value: 3.0354052136399536 at iteration 63
# function value: 2.9517871286740744 at iteration 64
# function value: 2.8704695004022573 at iteration 65
# function value: 2.791389203294234 at iteration 66
# function value: 2.714484835184087 at iteration 67
# function value: 2.639696670697205 at iteration 68
# function value: 2.5669666159102404 at iteration 69
# function value: 2.496238164212819 at iteration 70
# function value: 2.4274563533404505 at iteration 71
# function value: 2.3605677235488 at iteration 72
# function value: 2.2955202769001573 at iteration 73
# function value: 2.232263437633657 at iteration 74
# function value: 2.1707480135914357 at iteration 75
# function value: 2.1109261586735824 at iteration 76
# function value: 2.0527513362954024 at iteration 77
# function value: 1.9961782838210935 at iteration 78
# function value: 1.941162977948627 at iteration 79
# function value: 1.887662601021158 at iteration 80
# function value: 1.835635508240939 at iteration 81
# function value: 1.7850411957622745 at iteration 82
# function value: 1.7358402696406128 at iteration 83
# function value: 1.6879944156154534 at iteration 84
# function value: 1.6414663697052876 at iteration 85
# function value: 1.5962198895933175 at iteration 86
# function value: 1.552219726783236 at iteration 87
# function value: 1.5094315995048528 at iteration 88
# function value: 1.4678221663498683 at iteration 89
# function value: 1.4273590006185755 at iteration 90
# function value: 1.3880105653587498 at iteration 91
# function value: 1.349746189078475 at iteration 92
# function value: 1.3125360421150891 at iteration 93
# function value: 1.2763511136429013 at iteration 94
# function value: 1.2411631893027597 at iteration 95
# function value: 1.206944829436983 at iteration 96
# function value: 1.1736693479135896 at iteration 97
# function value: 1.1413107915241647 at iteration 98
# function value: 1.1098439199401016 at iteration 99
# function value: 1.0792441862123598 at iteration 100
# Final value of theta where f2 is the lowest:[-2.99892973  2.96113509]

# %% [markdown]
# # Naive Bayes Classifier - 3rd Question

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import shuffle
import math

# %%
boys_names = pd.read_csv('3/boy_names.csv')
girls_names = pd.read_csv('3/girl_names-2.csv')
test_names = pd.read_csv('3/test_names.csv')

# %%
b = boys_names.x
g = girls_names.x
test = pd.DataFrame(np.array(test_names.x), columns=['Names'])

# %%
df = pd.DataFrame(np.append(b,g),columns=['Names'])
df['Gender'] = np.array([-1]*1000+[1]*1000)

# %%
# Referred the following link to generate features
# https://github.com/clintval/gender-predictor/blob/master/gender_predictor/__init__.py
consonants = "bcdfghjklmnpqrstvwxyz"
def generate_features(X):
    X['Names'] = X['Names'].str.lower()
    X['Start']  = X['Names'].str[0]
    X['Last'] = X['Names'].str[-1]
    X['Starts_With_Vowel'] = [X['Start'][i] in 'AEIOU'.lower() for i in range(len(X))]
    X['Starts_With_Consonant'] = [X['Start'][i] in consonants for i in range(len(X))]
    X['Ends_With_Vowel'] = [X['Last'][i] in 'AEIOU'.lower() for i in range(len(X))]
    X['Ends_With_Consonant'] = [X['Last'][i] in consonants for i in range(len(X))]
    X['First_two'] = X['Names'].str[:2]
    X_trans = X.drop('Names',axis=1)
    cols = list(filter(lambda x:x!='Gender',list(X_trans.columns)))
    for col in cols:
        X_trans[col] = LabelEncoder().fit_transform(X[col])
    return X_trans

# %%
X = generate_features(df)

# %%
X.head(5)
# Out:
#    Gender  Start  Last  Starts_With_Vowel  Starts_With_Consonant  \
# 0      -1     14    13                  1                      0
# 1      -1      2    10                  0                      1
# 2      -1      3    17                  0                      1
# 3      -1      4    21                  1                      0
# 4      -1      2    17                  0                      1
#
#    Ends_With_Vowel  Ends_With_Consonant  First_two
# 0                1                    0        132
# 1                0                    1         26
# 2                0                    1         35
# 3                0                    1         45
# 4                0                    1         31

# %%
get_mean = lambda feature,gender,X: np.mean(X[X.Gender==gender][feature])

# %%
get_variance = lambda feature,gender,X: np.var(X[X.Gender==gender][feature])

# %%
def get_means_and_variance(X):
    means_male = {}
    means_female = {}
    var_male = {}
    var_female = {}
    for col in X.columns[1:]:
        means_male[col] = get_mean(col,-1,X)
        means_female[col] = get_mean(col,1,X)
        var_male[col] = get_variance(col,-1,X)
        var_female[col] = get_variance(col,1,X)
    return {'means_male':means_male,'means_female':means_female,'var_male':var_male,'var_female':var_female}

# %%
X, y = shuffle(X,X.Gender)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
means_var = get_means_and_variance(X_train)

# %%
X_train = X_train.drop('Gender',axis=1)
X_test = X_test.drop('Gender',axis=1)

# %% [markdown]
# Assuming Gaussian Distribution and calculating the likelihoods.
#
# P0 is the likelihood for class -1 i.e P(X | Y=-1) (-1 is Male).
#
# P1 is the likelihood for class 1 i.e P(X | Y=1) (1 is Female).

# %%
def get_likelihoods_and_preds(X):
    P0 = []
    P1 = []
    preds = []
    for x in X.values:
        p1 = 1
        p0 = 1
        for i in range(len(np.array(X.columns))):
                k = 1/(math.sqrt(2*math.pi*means_var['var_male'][X.columns[i]]))
                exp = -((x[i]-means_var['means_male'][X.columns[i]])**2)/(2*means_var['var_male'][X.columns[i]])
                p0 = p0*k*np.exp(exp) #Multiplying the likelihoods of each feature.

                k = 1/(math.sqrt(2*math.pi*means_var['var_female'][X.columns[i]]))
                exp = -((x[i]-means_var['means_female'][X.columns[i]])**2)/(2*means_var['var_female'][X.columns[i]])
                p1 = p1*k*np.exp(exp)

        P1.append(p1)
        P0.append(p0)
        preds.append(1 if p1>p0 else -1) #Assigning a class based on likelihoods. 
    return {'P1':P1,'P0':P0, 'preds':preds}

# %%
X_trans = X.drop('Gender',axis=1)
d = get_likelihoods_and_preds(X_trans)
d['P1'] #P(X | Y=1)
d['P0']#P(X | Y=-1)
# Out:
# [2.2917328444130363e-06,
#  4.816273784904094e-06,
#  1.574307015331592e-09,
#  5.2259664599658654e-08,
#  9.313626799254083e-06,
#  7.971439036175164e-06,
#  7.592826715990547e-07,
#  1.0139870289920056e-05,
#  3.647388152982773e-07,
#  5.893183991749555e-10,
#  3.116507922987928e-06,
#  5.163232815116855e-07,
#  2.7259996153330832e-06,
#  1.347888815368406e-07,
#  3.193282463588945e-08,
#  5.095991637525251e-08,
#  1.5042482419701578e-07,
#  6.41639515225933e-10,
#  ...]

# %%
accuracy_score(y_test,get_likelihoods_and_preds(X_test)['preds'])
# Out:
# 0.7466666666666667

# %% [markdown]
# P(Y=1) and P(Y=-1) are the probabilities of either being a boy or girl. And they both are the same i.e 1/2.

# %% [markdown]
# Log Probabilities. log(P(Y=1 | X) / P(Y=-1 | X)).
#
# We know that,
# P(Y=1 | X) is proportional to P(X1 | Y).P(X2 | Y)...P(Xd | Y).P(Y), we can ignore P(Y) because its constant and same.
#
# So,
# P(Y=1 | X) = P1 i.e Likelihood for class 1.
#
# P(Y=-1 | X) = P0 i.e Likelihood for class -1

# %%
P1 = np.array(d['P1'])
P0 = np.array(d['P0'])
log_prob = np.log(P1/P0)

# %%
log_prob
# Out:
# array([-4.0445215 , -1.50178516,  4.68732026, ..., -3.0943996 ,
#         2.28125051, -5.17680399])

# %%
test_features = generate_features(test)

# %%
test_features.head(5)
# Out:
#    Start  Last  Starts_With_Vowel  Starts_With_Consonant  Ends_With_Vowel  \
# 0      1     5                  0                      1                1
# 1      1     9                  0                      1                0
# 2      3    14                  0                      1                0
# 3     17     0                  0                      1                1
# 4      5     0                  0                      1                1
#
#    Ends_With_Consonant  First_two
# 0                    0          7
# 1                    1          7
# 2                    1         14
# 3                    0         61
# 4                    0         22

# %%
preds = pd.DataFrame(get_likelihoods_and_preds(test_features)['preds'], columns=['Gender'])
preds.to_csv('test_preds.csv',index=False)

# %% [markdown]
# # Naive Bayes Classifier - 4th Question

# %% [markdown]
# Bayes assumption,
# P(X|Y = y) = P(X[1] | Y=y).P(X[2] | Y=y).....P(X[d] | Y=y).
#
# 'd' is the number of features

# %%
# Referred the following link 
# https://www.probabilitycourse.com/chapter1/1_4_4_conditional_independence.php

# %% [markdown]
# Lets consider 3 events as follows,
#
# A = {1,2,4}
# B = {2,5}
# C = {2,3}
#
# P(A) = 1/3
# P(B) = 1/3
# Now, according to bayes assumption,
# P(A^B | C) = P(A|C) * P(B|C)
#
# P(A^B) = {2}
# So, P(A^B | C} = 1/2
#
# P(A|C) = 1/3, P(B|C) = 1/2
# So, P(A|C)* P(B|C) = 1/6
#
# P(A^B|C) > P(A|C) * P(B|C)
#
# Now, lets assume C = {1,5}
#
# P(A|C) = 1/3
# P(B|C) = 1/2
# P(A^B|C) = 0
#
# P(A^B|C) < P(A|C) * P(B|C)

# %% [markdown]
# If the model is a full model, P(X | Y=c) can be written as follows,
# P(X | Y=c) = P(X1^X2^X3^....Xn) / P(Y=c).
#
# Here P(X1^X2^X3...Xd) can be written as,
# P(Xn | X1,X2,...Xn-1)P(Xn-1 | X1,X2,X3...Xn-2)...P(X2|X1)P(X1). '^' is intersection.
#
# If we assume that X is boolean vector here, then X can have 2^n possible values, where n is the the number of features.
# So, the number of parameters will approximately be 2^n.
#
# If the training size is too small, Naive Bayes would perform better because it does not assume any dependence between the features and it can easily compute the probabilities, and with a full bayesian model it would be very difficult to train the model because it is hard to derive a correlation between features with small amounts of data.
